# %% [raw]
#  Python is a case sensitive programming language (it means its a huge difference between lower case and upper case)

# %%
# Keywords

# %% [markdown]
# In programming a keyword is a word that is reserved by python because it has a special meaning. every programming
# language has a set of keywords.

# %%
# Python hass 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Identifiers

# %% [raw]
#  A python identifiers is name used to identify variable,function, class, module or other object.

# %% [raw]
# # rules for setting identifiers
# 1)can only start with alphabet or _
# 2)followed by 0 or more letters,_ ,digits
# 3) keyword cannot be used as an identifiers

# %%
_ = "Manish"
print(_)
# Out:
# Manish

# %%
first_name = "Manish"
print(first_name)
# Out:
# Manish

# %%
first-name = "Manish"
print(first-name)
# Out:
#   Cell In[5], line 1
#     first-name = "Manish"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
False = "Manish
print(False)
# Out:
#   Cell In[6], line 1
#     False = "Manish
#             ^
# SyntaxError: unterminated string literal (detected at line 1)
