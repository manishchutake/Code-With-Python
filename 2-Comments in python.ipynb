# %%
# comments( a piece of code which is not executable by compiler or interpritor)
# it is used to give some headings or notes to understand the code .

# %%
# this is a comment (you cant write a multiple line comment if you want to write 
# you need to attach every line starting with #.
