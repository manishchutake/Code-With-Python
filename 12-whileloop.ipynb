# %% [raw]
# # while loop

# %%
#while condition:
   # code

# %%
number = int(input("Enter the number:"))
i = 1
while i<11:
    print(number * i)
    i+=1
# Out:
# Enter the number: 11
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110

# %%
number = int(input("Enter the number:"))
i = 1
while i<11:
    print(number,"*", "=", number * i)
    i+=1
# Out:
# Enter the number: 24
# 24 * = 24
# 24 * = 48
# 24 * = 72
# 24 * = 96
# 24 * = 120
# 24 * = 144
# 24 * = 168
# 24 * = 192
# 24 * = 216
# 24 * = 240
