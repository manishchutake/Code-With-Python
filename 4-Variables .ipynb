# %%
name = "Manish"
print(name)
# Out:
# Manish

# %%
# no variable declaration

# %%
# Dynamic typing
#Static typing

# %%
print(name)
# Out:
# Manish

# %%
name = 4

# %%
print(name)
# Out:
# 4

# %%
# Dynamic binding

# %%
# static binding
 #int a = 4;

# %%
# Special syntax

# %%
a=5; b=6; c=7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a, b, c = 4, 5, 6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a= b = c =6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
