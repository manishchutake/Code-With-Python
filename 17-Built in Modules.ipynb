# %% [raw]
# What are Modules?
# Code libraries in Python.
# Contain functions for use.
# Examples:
#
# Math: Math ops
# Random: Random numbers
# os: OS interaction
# time: Time tasks

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# 2026-03-28 18:50:10.245488: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pkgutil.py:92: FutureWarning: The 'optree.integration' module is deprecated and will be removed in version 0.18.0. Please use 'optree.integrations' instead.
#   __import__(info.name)
# ...

# %%
import math

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.asin
# Out:
# <function math.asin(x, /)>

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
import random

# %%
random.randint(1, 100)
# Out:
# 61

# %%
a = ([2,4,6,7,8])
random.shuffle(a)
print(a)
# Out:
# [2, 7, 6, 8, 4]

# %%
import time

# %%
time.time()
# Out:
# 1774704845.675452

# %%
time.ctime()
# Out:
# 'Sat Mar 28 19:04:18 2026'

# %%
print("Hello")
time.sleep(5)
print("world") #world will pprint after 5 seconds
# Out:
# Hello
# world

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/manishuxuid/python challenge '

# %%
os.listdir()
# Out:
# ['7)Literals.ipynb',
#  '6)Type conversion.ipynb',
#  '15)Break,Continue, Pass.ipynb',
#  '16)Buil in Functions.ipynb',
#  '3)Data_Types.ipynb',
#  '5)User input.ipynb',
#  'Built in Modules.ipynb',
#  '9) if else statement.ipynb',
#  '1)Print Function.ipynb',
#  '12) Guessing game.ipynb',
#  '10) Indentation.ipynb',
#  '5)Keywords and identifiers.ipynb',
#  '8)Operators.ipynb',
#  '13)ForLoops.ipynb',
#  '.ipynb_checkpoints',
#  '2)Comments in python.ipynb',
#  '11)whileloop.ipynb',
#  '4)Variables .ipynb',
#  '14)Nested loops.ipynb']
