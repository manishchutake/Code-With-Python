# %% [markdown]
# # String Functions

# %% [raw]
# String Functions
# 1. Common Functions
# len()
# max()
# min()
# sorted()

# %%
c  = "Kolkata"
print(len(c))
# Out:
# 7

# %%
max(c)
# Out:
# 't'

# %%
min(c)
# Out:
# 'K'

# %%
sorted(c)
# Out:
# ['K', 'a', 'a', 'k', 'l', 'o', 't']

# %% [markdown]
# # 1.Capitalize/Title/Upper/Lower/Swapcase

# %%
c 
c.capitalize()
c
# Out:
# 'Kolkata'

# %%
"it is raining today".capitalize()
# Out:
# 'It is raining today'

# %%
"it is raining today".title()
# Out:
# 'It Is Raining Today'

# %%
c.upper().lower()
# Out:
# 'kolkata'

# %%
"LocUKnow".swapcase()
# Out:
# 'lOCukNOW'

# %% [markdown]
#  # 2.Count

# %%
"it is raining".count("i")
# Out:
# 4

# %%
"it is raining".count("ing")
# Out:
# 1

# %%
"it is raining".count("rain")
# Out:
# 1

# %%
"it is raining".count("pik")
# Out:
# 0

# %% [markdown]
# # Find and Index

# %%
"it is raining".find("g")
# Out:
# 12

# %%
"it is raining".find("raining")
# Out:
# 6

# %%
"it is raining".find("y")
# Out:
# -1

# %%
"it is raining".find("rain")
# Out:
# 6

# %%
"it is raining".index("rain")
# Out:
# 6

# %%
"it is raining".index("x")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 "it is raining".index("x")
#
# ValueError: substring not found

# %% [markdown]
# # Ends with and starts with

# %%
"it is raining".endswith("ing")
# Out:
# True

# %%
"it is raining".startswith("ing")
# Out:
# False

# %% [markdown]
# # Format

# %%
"Hello my name is {} and I am {}." .format("Manish", 33)
# Out:
# 'Hello my name is Manish and I am 33.'

# %%
"Hello my name is {1} and I am {0}." .format("Manish", 33)
# Out:
# 'Hello my name is 33 and I am Manish.'

# %%
"Hello my name is {name} and I am {age}." .format( name = "Manish", age =  33)
# Out:
# 'Hello my name is Manish and I am 33.'

# %% [markdown]
# # isalnum/isalpha/isdecimal/isdigit/isidentifier

# %%
"FLAT20".isalnum()
# Out:
# True

# %%
"FLAT20&".isalnum()
# Out:
# False

# %%
"FLAT".isalpha()
# Out:
# True

# %%
"20A". isdigit()
# Out:
# False

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# # Split

# %%
"who is the pm of india".split()
# Out:
# ['who', 'is', 'the', 'pm', 'of', 'india']

# %%
"who is the pm of india".split()

# %%
"who is the pm of india".split("pm")
# Out:
# ['who is the ', ' of india']

# %%
"who is the pm of india".split("i")
# Out:
# ['who ', 's the pm of ', 'nd', 'a']

# %%
"who is the pm of india".split("x")
# Out:
# ['who is the pm of india']

# %% [markdown]
# # Join

# %%
" ".join(['who', 'is', 'the', 'pm', 'of', 'india'])
# Out:
# 'who is the pm of india'

# %%
"-".join(['who', 'is', 'the', 'pm', 'of', 'india'])
# Out:
# 'who-is-the-pm-of-india'

# %% [markdown]
# # Replace

# %%
"Hi my name is Nitish".replace("Nitish", "Manish")
# Out:
# 'Hi my name is Manish'

# %% [markdown]
# # Strip

# %%
name = "      Manish      "
'Hi' + name
# Out:
# 'Hi      Manish      '

# %%
name = "      Manish      "
name.strip()
# Out:
# 'Manish'
