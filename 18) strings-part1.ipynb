# %% [raw]
# strings are sequence of characters
# In python, specially strings are unicode characters
#
#
# 1)creating strings
# 2)accessing strings
# 3)adding chars to string
# 4)editing strings
# 5)deleting strings
# 6)operations on strings
# 7)string functions

# %%
c = 'Hello'
print(c)
# Out:
# Hello

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
"It's raining outside"
# Out:
# "It's raining outside"

# %%
c = """ hello""" # use for multiline string
print(c)
# Out:
#  hello

# %%
c = '''hello'''
print(c)
# Out:
# hello
