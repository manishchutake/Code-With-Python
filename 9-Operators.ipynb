# %% [raw]
# operators are used to perform operators on variables and values. Python has following operators .
# 1)Arithmatic operators
# 2)Comparision operators
# 3)Logical operators
# 4)Bitwise operators
# 5)Assignment operators
# 6)Identity operators
# 7)Membership operators

# %% [raw]
# Operators in Python
# Arithmetic: +, -, *, /, %, **, //
# Comparison: ==, !=, >, <, >=, <=
# Logical: and, or, not
# Bitwise: &, |, ^, ~, <<, >>
# Assignment: =, +=, -=, *=, /=, %=, **=, //=
# Identity: is, is not
# Membership: in, not in

# %%
#1) Arithmatic operators

# %%
x = 5
y = 2
print(x+y)
# Out:
# 7

# %%
print(x-y)
# Out:
# 3

# %%
print(x*y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 2.5

# %%
print(x//y)
# Out:
# 2

# %%
print(x**y)
# Out:
# 25

# %%
print(x%y)
# Out:
# 1

# %%
#2) Comparision operators

# %%
print(x>y)
# Out:
# True

# %%
print(x<y)
# Out:
# False

# %%
print(x <= y)
# Out:
# False

# %%
print(x>=y)
# Out:
# True

# %%
print(x==y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
#3)Logical operators

# %%
x = True
y = False
print(x or y)
# Out:
# True

# %%
print(x and y)
# Out:
# False

# %%
print( not y)
# Out:
# True

# %%
print(not x)
# Out:
# False

# %%
#4)Bitwise operators

# %%
x = 2
y = 3
print(x & y)
# Out:
# 2

# %%
print (x| y)
# Out:
# 3

# %%
print(x<<2)
# Out:
# 8

# %%
print(y>>3)
# Out:
# 0

# %%
#5) assignment operatorrs

# %%
a = 3
print(a)
# Out:
# 3

# %%
a +=3
print(a)
# Out:
# 6

# %%
a-=3
print(a)
# Out:
# 3

# %%
#6)Identity operators

# %%
a = 3
b = 3
print(a is not b)
# Out:
# False

# %%
print(a is b)
# Out:
# True

# %%
a = [1,2,3]
b = [1,2,3]

print(a is b) # if a and b is sam value but in python both are not same every time in python.
# Out:
# False

# %%
#7) Membership Operators

# %%
x = 'Delhi'
print('D' in x)
# Out:
# True

# %%
x = [1,2,3]
print(3 in x)
# Out:
# True

# %%
print(5 in x)
# Out:
# False
