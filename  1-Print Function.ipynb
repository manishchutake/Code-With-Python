# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5.5)
# Out:
# 5.5

# %%
print(6)
# Out:
# 6

# %%
print("Nepal","America", "India", "Australia")
# Out:
# Nepal America India Australia

# %%
print("India", 5, True)
# Out:
# India 5 True

# %%
# If you want to see functions then press shift tab.

# %%
print("Nepal","America", "India", "Australia", sep='/')
# Out:
# Nepal/America/India/Australia

# %%
print("Nepal","America", "India", "Australia", sep='-')
# Out:
# Nepal-America-India-Australia

# %%
print("Hello")
print("world")
# Out:
# Hello
# world

# %%
print("Hello", end= ' ')
print("world")
# Out:
# Hello world
