# %%
# email = manishdstech@gmail.com
#password = 1234


email = input("enter the email:")
password = input("enter password:")
if email == "manishdstech@gmail.com"and password == "1234":
    print("Welcome")
else:
    print("incorrect email or password")
# Out:
# enter the email: manishdstech@gmail.com
# enter password: 1234
# Welcome

# %%
#elif

# %%
# email = manishdstech@gmail.com
#password = 1234


email = input("enter the email:")
password = input("enter password:")
if email == "manishdstech@gmail.com"and password == "1234":
    print("Welcome")
elif email=="manishdstech@gmail.com" and password != "1234":
    print("incorrect password")  
    password = input("enter correct password:")
    if password == "1234":
        print("finally correct")
    else:("Still incorrect")
else:
    print("incorrect email or password")
# Out:
# enter the email: manishdstech@gmail.com
# enter password: 3456
# incorrect password
# enter correct password: 1234
# finally correct
