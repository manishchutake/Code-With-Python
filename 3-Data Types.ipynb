# %% [raw]
# # Python supports 3 types of data types :-
# . Basic Types=(integer,float, complex, boolean, string)
# . Container types=(List, Tuples, Set, Dictionary)
# . User-definedtypes=Class

# %%
# integer (basically a number)
print(4)
# Out:
# 4

# %%
#float(basically decimal number )
print(4.5)
# Out:
# 4.5

# %%
#Boolean(basically True and False)
print(True)
print(False)
# Out:
# True
# False

# %%
#Complex
print(4+ 5j)
# Out:
# (4+5j)

# %%
#String
print('Mumbai')
print("Mumbai")
print('''Mumbai''')
print("""Mumbai""")
# Out:
# Mumbai
# Mumbai
# Mumbai
# Mumbai

# %%
# List 
items = ["Sugar","Oil", "Kerosene", "Choclates"]

# %%
print(type(items))
# Out:
# <class 'list'>

# %%
# Tuples
num = (2, 4, 7, 8, 8)

# %%
print(type(num))
# Out:
# <class 'tuple'>

# %%
# Sets
num1 = {2, 6,4 ,5, 7 }

# %%
print(type(num1))
# Out:
# <class 'set'>

# %%
# Dictionary
dict = {"name":"Nitish", "age": 30, "gender":"male"}

# %%
print(type(dict))
# Out:
# <class 'dict'>
