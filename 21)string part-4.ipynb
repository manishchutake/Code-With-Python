# %% [markdown]
# # String Operations

# %% [raw]
# Operationss on Strings
# Arithmetic: Concatenation (+), Repetition (*)
# Relational: Equality (==), Inequality (!=), Comparison (<, >, <=, >=)
# Logical: and, or, not
# Loops: for loop, while loop
# Membership: in, not in

# %%
#Arithmatic operations

# %%
"Hello" + ' ' + "world" #concatenation (addition)
# Out:
# 'Hello world'

# %%
print("*"* 50)
# Out:
# **************************************************

# %%
print("Hello"* 4)
# Out:
# HelloHelloHelloHello

# %%
#Relational operators

# %%
"Hello" == "World"
# Out:
# False

# %%
"Hello" != "World"
# Out:
# True

# %%
"Mumbai" > "Pune"
# Out:
# False

# %%
"Mumbai" < "Pune"
# Lexiographically m is first come as compare to p so m is small p is big.
# Out:
# True

# %%
"Goa" < "kolkata"
# Out:
# True

# %%
"mum" >"Mum"
# Out:
# True

# %%
 #Logical Operations

# %%
"Hello" and "World"
# Out:
# 'World'

# %%
"" --> False # empty string is false in python
"Manish" --> True # written string is true in python

# %%
"" and "Hello"
# Out:
# ''

# %%
"" or "Hello"
# Out:
# 'Hello'

# %%
not ""
# Out:
# True

# %%
# Loops Operators

# %%
c = "Hello World"
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
c = "Hello World"
for i in c[::-1]:
    print(i)
# Out:
# d
# l
# r
# o
# W
#
# o
# l
# l
# e
# H

# %%
# membership operators

# %%
print(c)
# Out:
# Hello World

# %%
'H' in c
# Out:
# True

# %%
'World' not in c
# Out:
# False
