# %%
if name == "xyz":
    line1
    line2
    line3
else:
    line1
    line2
    line3

# the blank space after if and else in line 1, 2, 3 is called as indentation . it shows that lines are 
#under if an else. space is taking by press tab also.
