# %% [markdown]
# # Editing and deleting strings

# %%
c= 'Hello'
print(c)
# Out:
# Hello

# %%
c[0] = 'X' # STRINGS ARE  NOT EDITED(IMMUTABLE DATATYPES)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
c = 'world'
print(c)
# Out:
# world

# %%
c[5] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c[5] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
#Deletion

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
c = "Hello"

print(c)
# Out:
# Hello

# %%
del c[0] # string does not delete perticular character
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del c[:3:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 del c[:3:2]
#
# TypeError: 'str' object does not support item deletion
