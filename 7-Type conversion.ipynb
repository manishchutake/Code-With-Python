# %%
#type
type([1, 2, 3, 4, 5])
# Out:
# list

# %%
type((1,2,3))
# Out:
# tuple

# %% [raw]
# There are two types of type conversion implicit and explicit

# %%
4 + 5.5
# Out:
# 9.5

# %%
int(5)
# Out:
# 5

# %%
float(4)
# Out:
# 4.0

# %%
str(5)
# Out:
# '5'

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
complex(4)
# Out:
# (4+0j)

# %%
list('Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
first_num = input("Enter the first num:")
second_num = input("Enter the second num:")
result = int(first_num) +int(second_num)
print(result)
# Out:
# Enter the first num: 24
# Enter the second num: 25
# 49

# %%
first_num = int(input("Enter the first num:"))
second_num = int(input("Enter the second num:"))
result = first_num + second_num
print(result)
# Out:
# Enter the first num: 24
# Enter the second num: 24
# 48
