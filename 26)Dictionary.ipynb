# %% [raw]
# Dictionary
# Key-Value Pairs: Data mapping.
# Aliases: Map, associative array.
# dict = { 'name': 'nitish', 'age': 33, 'gender': 'male' }
# Traits:
# Mutable
# No indexing
# Unique keys
# Immutable keys

# %% [raw]
#  Key Rules About Dictionaries
# No Indexing: No index support.
# Mutable: Can modify post-creation.
# Keys: Immutable (str, num, tuple); Values: Any type.
# Unique Keys: Keys must be unique; overwrite on reassignment.

# %% [raw]
# mutable --> list, sets, dictionary
# immutable --> strings, tuples,int, float, boolean, complex

# %%
{"Name": "Manish", "Gender" : "Male"}
# Out:
# {'Name': 'Manish', 'Gender': 'Male'}

# %%
D = {}

# %%
D
# Out:
# {}

# %%
D = {"Name": "Manish", "Gender" : "Male"}

# %%
D
# Out:
# {'Name': 'Manish', 'Gender': 'Male'}

# %%
D1 = {[1,2,3]:"Manish"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 D1 = {[1,2,3]:"Manish"}
#
# TypeError: unhashable type: 'list'

# %%
D1 = {(1,2,3):"Manish"} # keys are in setes sets are mutable

# %%
D1
# Out:
# {(1, 2, 3): 'Manish'}

# %%
# keys always immutable

# %%
D = {"Name": "Manish", "Name" : "Male"}

# %%
D
# Out:
# {'Name': 'Male'}

# %%
D3 = {"Name": "Rohit", "Collage" : "HIT", "Marks":{"M1":56, "DS":56,"ENG": 67}}
D3
# Out:
# {'Name': 'Rohit', 'Collage': 'HIT', 'Marks': {'M1': 56, 'DS': 56, 'ENG': 67}}

# %% [markdown]
# # Acees

# %%
D={"Name": "Manish", "Gender" : "Male"}

# %%
D
# Out:
# {'Name': 'Manish', 'Gender': 'Male'}

# %%
D[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 D[0]
#
# KeyError: 0

# %%
D["Name"]
# Out:
# 'Manish'

# %% [markdown]
# # EDIT

# %%
D3
# Out:
# {'Name': 'Rohit', 'Collage': 'HIT', 'Marks': {'M1': 56, 'DS': 56, 'ENG': 67}}

# %%
D3["Marks"]
# Out:
# {'M1': 56, 'DS': 56, 'ENG': 67}

# %%
D3["Marks"]["DS"]
# Out:
# 56

# %%
D
# Out:
# {'Name': 'Manish', 'Gender': 'Male'}

# %%
D["Name"] = "Rahul"

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male'}

# %%
D3["Marks"]["DS"] =65

# %%
D3
# Out:
# {'Name': 'Rohit', 'Collage': 'HIT', 'Marks': {'M1': 56, 'DS': 65, 'ENG': 67}}

# %% [markdown]
# # ADD

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male'}

# %%
D["AGE"] = 34

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male', 'AGE': 34}

# %%
D3["Marks"]["st"] = 47

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'Collage': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}}

# %%
D5 ={}

# %%
D5
# Out:
# {}

# %%
del D5

# %% [markdown]
# # Operations

# %%
D1
# Out:
# {(1, 2, 3): 'Manish'}

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'Collage': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}}

# %%
D1 +D3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 D1 +D3
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D3*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 D3*2
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
for i in D3:
    print(i)
# Out:
# Name
# Collage
# Marks

# %%
for i in D3:
    print(i,D3[i])
# Out:
# Name Rohit
# Collage HIT
# Marks {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'Collage': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}}

# %%
"Rohit" in D3
# Out:
# False

# %%
"Name" in D3
# Out:
# True

# %% [markdown]
# # Functions

# %%
len(D3)
# Out:
# 3

# %%
min(D3)
# Out:
# 'Collage'

# %%
max(D3)
# Out:
# 'Name'

# %%
sorted(D3)
# Out:
# ['Collage', 'Marks', 'Name']

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'Collage': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}}

# %%
D3.keys()
# Out:
# dict_keys(['Name', 'Collage', 'Marks'])

# %%
D3.values()
# Out:
# dict_values(['Rohit', 'HIT', {'M1': 56, 'DS': 65, 'ENG': 67, 'st': 47}])
