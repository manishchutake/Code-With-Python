# %% [markdown]
# User Input

# %%
input()
# Out:
#  56
# '56'

# %%
input("email")
# Out:
# email manishdstech@gmail.com
# 'manishdstech@gmail.com'

# %%
a = input("Enter the first num")
b = input("enter the second num")
print(a+b)
# Out:
# Enter the first num 34
# enter the second num 34
# 3434

# %%
# whenever you take input its always come in string format

# %%
a= int(input("Enter your first num"))
b = int(input("Enter your ssecond num"))
print(a+b)
# Out:
# Enter your first num 25
# Enter your ssecond num 25
# 50
